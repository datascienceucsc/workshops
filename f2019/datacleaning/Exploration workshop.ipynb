# %% [markdown]
# # Workshop 1: Data cleaning and exploration
# *Anders Poirel and Oasys Okubo*
# *30-09-2019*
#
# First we import a few of the usual libraries used for data analysis in Python

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Read in the data. Make sure the `.csv` file is in the same folder as this notebook.

# %%
data = pd.read_csv('registration_responses.csv')

# %% [markdown]
# ## 1 Cleaning

# %% [markdown]
# Data acquired in the real world is rarely immediately fit for data analysis. Often, formatting and names will be inconsistent and there may be missing entries. In fact, data acquisition, cleaning and preparation is often reported to take >80% of the time of data scientists working in industry, so while it may be more boring than building models, it's an important skill to master.

# %% [markdown]
# As an example, we'll use the data we collected at Cornucopia:

# %%
data.head(15)
# Out:
#              Timestamp      Email Address             Name  \
# 0   9/24/2019 11:46:12  rgdarlin@ucsc.edu             Ryan
# 1   9/24/2019 11:46:19   apoirel@ucsc.edu    Anders Poirel
# 2   9/24/2019 16:02:55   apoirel@ucsc.edu            Edwin
# 3   9/24/2019 16:03:46   apoirel@ucsc.edu       David Park
# 4   9/24/2019 16:04:47   apoirel@ucsc.edu   Quinn Chalmers
# 5   9/24/2019 16:06:43   apoirel@ucsc.edu      Eric Truong
# 6   9/24/2019 16:08:40   apoirel@ucsc.edu     nikhil sheth
# 7   9/24/2019 16:09:40   apoirel@ucsc.edu      Eugene Shin
# 8   9/24/2019 16:13:02   apoirel@ucsc.edu       Jason Yang
# 9   9/24/2019 16:13:38   apoirel@ucsc.edu           Gopala
# 10  9/24/2019 16:15:11   apoirel@ucsc.edu   Navneet Pathak
# 11  9/24/2019 16:16:39   apoirel@ucsc.edu  Sanyam Sachdeva
# 12  9/24/2019 16:17:24   apoirel@ucsc.edu   Balaram Behera
# 13  9/24/2019 16:19:33   apoirel@ucsc.edu        Tim Zhang
# 14  9/24/2019 16:20:15   apoirel@ucsc.edu      Brian Duong
#
#                          Email Phone number (xxx) xxx-xxxx  \
# 0            rgdarlin@ucsc.edu                  5305649868
# 1             apoirel@ucsc.edu              (415) 324-9472
# 2            egarciah@ucsc.edu                510-334-6382
# 3             mpark30@ucsc.edu                  2133791363
# 4            qchalmer@ucsc.edu                  6612998511
# 5            ermtruon@ucsc.edu              (669) 265-9732
# 6             npsheth@ucsc.edu                925-577-8542
# 7             eshin3@gmail.com               (650)922-0053
# 8            jyang206@ucsc.edu                  5105987120
# 9            gnadadhu@ucsc.edu                  8312972117
# 10           napathak@ucsc.edu              (408) 219-2297
# 11           ssachde3@ucsc.edu                  5592876393
# 12            bbehera@ucsc.edu                  5109363079
# 13           yzhan596@ucsc.edu                  5107899297
# 14  brianduong122333@gmail.com                  9253517575
#
#                          Major(s)                 Year
# 0     Computational Math and Econ         Fourth Year
# 1   Computer Science, Mathematics               Junior
# 2                             NaN                  1st
# 3                              cs                 2023
# 4                             TIM               Senior
# 5            Computer Engineering               Second
# 6                        Comp Sci                 2020
# 7                  cs game design               Junior
# 8            Computer Engineering                 2023
# 9                             NaN                  NaN
# 10               Computer Science                Frosh
# 11               Computer Science               Junior
# 12                        CS/math  3rd year (transfer)
# 13                             CS          Transfer Jr
# 14               Computer Science    Transfer 1st year

# %%
data.tail(15)
# Out:
#     Timestamp Email Address              Name                       Email  \
# 164       NaN           NaN              Matt           mtjacobs@ucsc.edu
# 165       NaN           NaN        Max Nakama           manakama@ucsc.edu
# 166       NaN           NaN             Tyler              tkhun@ucsc.edu
# 167       NaN           NaN  Aakaash Narayann           anaraya4@ucsc.edu
# 168       NaN           NaN       Joey Barcia            jbarcia@ucsc.edu
# 169       NaN           NaN     Brian Pereira           brpereir@ucsc.edu
# 170       NaN           NaN       Jason Harpe           jaaharpe@ucsc.edu
# 171       NaN           NaN      Richard Thai             rithai@ucsc.edu
# 172       NaN           NaN    Shreyas Ketkar            sketkar@ucsc.edu
# 173       NaN           NaN       Smeet Mehta           smsmetha@ucsc.edu
# 174       NaN           NaN  Rafael Vanderzee          rvanderz@gmail.com
# 175       NaN           NaN          Jason Li              jadli@ucsc.edu
# 176       NaN           NaN               NaN           hmedina3@ucsc.edu
# 177       NaN           NaN               NaN            estepro@ucsc.edu
# 178       NaN           NaN   Jeremy Gurganus  gurganusjeremy93@gmail.com
#
#                            Phone number (xxx) xxx-xxxx Major(s) Year
# 164                                     (408) 623-1752      NaN  NaN
# 165                                     (510) 695-6425      NaN  NaN
# 166                                     (650) 288-7227      NaN  NaN
# 167                                                NaN      NaN  NaN
# 168  (805) 636-0702                                ...      NaN  NaN
# 169                                     (510) 686-0018      NaN  NaN
# 170                                     (510) 372-6160      NaN  NaN
# 171                                                NaN      NaN  NaN
# 172                                                NaN      NaN  NaN
# 173                                     (831) 226-6555      NaN  NaN
# 174                                     (661) 609-0069      NaN  NaN
# 175                                   (408) 691-7165\n      NaN  NaN
# 176                                       323-392-6317      NaN  NaN
# 177                                                NaN      NaN  NaN
# 178                                                NaN      NaN  NaN

# %% [markdown]
# ### 1.1  Major

# %% [markdown]
# We'll start by cleaning up the majors data. The below code reshapes the data to group it by major, selects only the `Major(s)` column and then aggregates using `count` to find how many times each category appears:

# %%
data.groupby('Major(s)')['Major(s)'].count()
# Out:
# Major(s)
# AGPM                                         1
# BME                                          4
# Bio                                          1
# Bioinformatics                               1
# Biology                                      1
# Biomolecular Engineering and Informatics     1
# Business management economics                2
# CE                                           6
# CS                                          26
# CS & Comp. Math                              1
# CS BS                                        1
# CS, Global Economics                         2
# CS/math                                      1
# CS: Game Design                              1
# CSE                                          1
# CSGD                                         1
# Cognitive Science                            2
# Cognitive science                            1
# Comp Engineering                             1
# Comp Sci                                     2
# Comp math                                    1
# Comp sci                                     1
# Comp. SCIENCE                                1
# CompSci                                      1
# Computational Math and Econ                  1
# Computer Engineering                         2
# Computer Science                            21
# Computer Science                             4
# Computer Science & Stats minor               1
# Computer Science Game Design                 1
#                                             ..
# Environmental Studies, Engineering           1
# Math                                         2
# Mathematics                                  1
# Proposed TIM                                 1
# Robotics                                     1
# Statistical science                          1
# TIM                                          6
# Technology, Information & Management         1
# Undeclared                                   1
# applied Math                                 1
# ce                                           1
# cog sci                                      2
# comp sci                                     1
# compsci                                      1
# computational mathematics                    1
# computational media                          1
# computer Science                             2
# computer science                             5
# computer science                             1
# cs                                           7
# cs game design                               1
# declared sci-                                1
# econ                                         1
# econ with stats minor                        1
# econ/math                                    1
# f                                            1
# mathematics                                  1
# physics                                      1
# psc.                                         1
# undeclared math/science                      1
# Name: Major(s), Length: 72, dtype: int64

# %% [markdown]
# We begin by filling in missing entries with "No response" (No answer can be a meaningful category of its own in many situations)

# %%
data = data.fillna('No response')

# %%
data.replace(to_replace = ['CS', 'CS BS', 'Comp sci', 'Comp Sci', 'CompSci',
                           'cs', 'comp sci', 'compsci', 'computer science', 'computer Science', 
                           'Comp. SCIENCE', 'computer science ', 'Computer Science and Engineering',
                           'cse', 'Computer Scince', 'Computer science', 'CSE', 'Computer Science ',
                           'Computer Science & Stats minor', 
                           'Computer Science, possible Robotics Engineering'
                          ],
    value = 'Computer Science',
    inplace = True)

# %%
data.replace(to_replace = ['ce', 'CE', 'Computer Engineering', 'Comp Engineering', 'ECE', 'Engineering'],
            value = 'Computer Engineering', inplace = True)

# %%
data.replace(to_replace = ['CS & Comp. Math' , 'CS/math', 'Computer Science, Mathematics'],
            value = 'Computer Science, Mathematics', inplace = True)

# %%
data.replace(to_replace = ['Comp math', 'Math', 'Mathematics', 'mathematics', 'applied math',
                          'applied Math', 'computational mathematics'],
            value = 'Mathematics', inplace = True)

# %%
data.replace(to_replace = ['CS: Game Design', 'CSGD', 'cs game design', 'Computer Science Game Design'],
            value = 'Computer Science: Game Design', inplace = True)

# %%
data.replace(to_replace = ['Cognitive Science', 'Cognitive science', 'cog sci'],
             value = 'Cognitive Science', inplace = True)

# %%
data.replace(to_replace = ['Econ+Math', 'econ/math', 'Computational Math and Econ'], 
             value = 'Mathematics, Economics',
             inplace = True)

# %%
data.replace(to_replace = ['Computer Science/Cog Sci', 'Computer Science and Artificial Intelligence', 
                          'Computer Science and Cognitive Science '],
             value = 'Cognitive Science, Computer Science', inplace = True)

# %%
data.replace(to_replace = ['Business management economics','econ', 'econ with stats minor'],
            value = 'Economics', inplace = True)

# %%
data.replace(to_replace = ['BME', 'Biomolecular Engineering and Informatics'],
            value = 'Biomolecular Engineering', inplace = True)

# %%
data.replace(to_replace = ['TIM', 'Proposed TIM', 'Technology, Information & Management'],
            value = 'Technology, Information & Management', inplace = True)

# %%
data.replace(to_replace = ['undeclared math/science'], value = 'Undeclared', inplace = True)

# %%
data.replace(to_replace = ['Bio'], value = 'Biology', inplace = True)

# %% [markdown]
# Cleaning up the remaining entries using the dictionary syntax for `replace`:

# %%
data.replace(to_replace = {
    'Economics, TIM': 'Ecomomics, Technology, Information & Management',
    'computational media' : 'Computational Media',
    'physics ' : 'Physics',
    'f' : 'No response',
    'declared sci-' : 'No response',
    'psc.' : 'Psychology',
    'CS, Global Economics' : 'Computer Science, Economics'
}, inplace = True)

# %%
data.groupby('Major(s)')['Major(s)'].count()
# Out:
# Major(s)
# AGPM                                                1
# Bioinformatics                                      1
# Biology                                             2
# Biomolecular Engineering                            5
# Cognitive Science                                   5
# Cognitive Science, Computer Science                 3
# Computational Media                                 1
# Computer Engineering                               12
# Computer Science                                   80
# Computer Science, Economics                         2
# Computer Science, Mathematics                       3
# Computer Science: Game Design                       4
# Ecomomics, Technology, Information & Management     1
# Economics                                           4
# Environmental Studies, Engineering                  1
# Mathematics                                         7
# Mathematics, Economics                              3
# No response                                        30
# Physics                                             1
# Psychology                                          1
# Robotics                                            1
# Statistical science                                 1
# Technology, Information & Management                8
# Undeclared                                          2
# Name: Major(s), dtype: int64

# %% [markdown]
# ### 1.2 Year

# %% [markdown]
# Like before, we want to see what are all the different categories of entries for `Year`

# %%
data.groupby('Year')['Year'].count()
# Out:
# Year
# !st                        1
# 1                          9
# 1st                        9
# 1st year                   1
# 2                         13
# 2000                       1
# 2019                       1
# 2020                       5
# 2021                       3
# 2022                       8
# 2023                      19
# 22                         1
# 2nd                        5
# 2rd                        2
# 3                         11
# 3rd                        6
# 3rd year                   1
# 3rd year (transfer)        1
# 4                          1
# 4th                        9
# FROSH                      1
# First                      1
# First Year                 1
# Fourth Year                1
# Freshman                   2
# Freshman                   1
# Freshman year. (2019)      1
# Frosh                      2
# Grad 2020                  1
# Grad MS                    1
# Jr                         1
# Junior                     8
# Junior                     1
# No response               30
# Second                     1
# Senior                     3
# Sophomore                  2
# Third                      1
# Transfer                   2
# Transfer 1st year          1
# Transfer Jr                1
# c/o 2023                   1
# fourth                     1
# freshman                   1
# frosh                      1
# grad                       1
# j                          1
# junior                     1
# senior                     1
# sophomore                  1
# Name: Year, dtype: int64

# %% [markdown]
# What we did above gets really tedious We''l use the fancier way of finding and replacing entries using regular expressions. Notice that we could very well hardcode all of this with `data.replace` if we wanted.

# %%
import re
for d, i in enumerate(data['Year']):
    if re.search('fr|fir|2023|1st|1', i, re.IGNORECASE):
        data['Year'][d] = 'Freshman'
    elif re.search('sop|sec|2022|2nd|2|22', i, re.IGNORECASE):
        data['Year'][d] = 'Sophomore'
    elif re.search('jun|thi|2021|3rd|3|jr|j|tran', i, re.IGNORECASE):
        data['Year'][d] = 'Junior'
    elif re.search('sen|fou|2020|4|4th', i, re.IGNORECASE):
        data['Year'][d] = 'Senior'
    elif re.search('gra', i, re.IGNORECASE):
        data['Year'][d] = 'Graduate'

# %% [markdown]
# Alternatively, we could pass the regex directly into the pandas `replace`.

# %%
data.replace(to_replace = '!st', value = 'Freshman', inplace = True)

# %%
data.groupby('Year')['Year'].count()
# Out:
# Year
# Freshman       56
# Graduate        2
# Junior         35
# No response    30
# Senior         16
# Sophomore      40
# Name: Year, dtype: int64

# %% [markdown]
# ### 1.3 Phone numbers

# %%
data['Area'] = [np.nan for i in range(0, data.shape[0])]

# %%
for d, i in enumerate(data['Phone number (xxx) xxx-xxxx']):
    if i is not "No response":
        new_num = re.sub("\D", "", i)
        if len(new_num) is 10: # Check if it phone number is length of 10
            newid = '(' +new_num[0:3] + ') ' + new_num[3:6] + "-" + new_num[6:10]
            data['Phone number (xxx) xxx-xxxx'][d] = newid
            data['Area'][d] = new_num[0:3]
        else: # Otherwise, there may be an area code or invalid phone number
            data['Phone number (xxx) xxx-xxxx'][d] = 'No response'
# Out:
# C:\Users\Anders\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Anders\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\Anders\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %% [markdown]
# Now that we have numbers we can extract geographical location from the area code:

# %%
data.head(20)
# Out:
#              Timestamp      Email Address             Name  \
# 0   9/24/2019 11:46:12  rgdarlin@ucsc.edu             Ryan
# 1   9/24/2019 11:46:19   apoirel@ucsc.edu    Anders Poirel
# 2   9/24/2019 16:02:55   apoirel@ucsc.edu            Edwin
# 3   9/24/2019 16:03:46   apoirel@ucsc.edu       David Park
# 4   9/24/2019 16:04:47   apoirel@ucsc.edu   Quinn Chalmers
# 5   9/24/2019 16:06:43   apoirel@ucsc.edu      Eric Truong
# 6   9/24/2019 16:08:40   apoirel@ucsc.edu     nikhil sheth
# 7   9/24/2019 16:09:40   apoirel@ucsc.edu      Eugene Shin
# 8   9/24/2019 16:13:02   apoirel@ucsc.edu       Jason Yang
# 9   9/24/2019 16:13:38   apoirel@ucsc.edu           Gopala
# 10  9/24/2019 16:15:11   apoirel@ucsc.edu   Navneet Pathak
# 11  9/24/2019 16:16:39   apoirel@ucsc.edu  Sanyam Sachdeva
# 12  9/24/2019 16:17:24   apoirel@ucsc.edu   Balaram Behera
# 13  9/24/2019 16:19:33   apoirel@ucsc.edu        Tim Zhang
# 14  9/24/2019 16:20:15   apoirel@ucsc.edu      Brian Duong
# 15  9/24/2019 16:29:05   apoirel@ucsc.edu       Matt Atiqi
# 16  9/24/2019 16:29:47   apoirel@ucsc.edu  samuel indurkar
# 17  9/24/2019 16:31:37   apoirel@ucsc.edu        Noah West
# 18  9/24/2019 16:32:52   apoirel@ucsc.edu             Jake
# 19  9/24/2019 16:34:13   apoirel@ucsc.edu     Swetha Thiru
#
#                          Email Phone number (xxx) xxx-xxxx  \
# 0            rgdarlin@ucsc.edu              (530) 564-9868
# 1             apoirel@ucsc.edu              (415) 324-9472
# 2            egarciah@ucsc.edu              (510) 334-6382
# 3             mpark30@ucsc.edu              (213) 379-1363
# 4            qchalmer@ucsc.edu              (661) 299-8511
# 5            ermtruon@ucsc.edu              (669) 265-9732
# 6             npsheth@ucsc.edu              (925) 577-8542
# 7             eshin3@gmail.com              (650) 922-0053
# 8            jyang206@ucsc.edu              (510) 598-7120
# 9            gnadadhu@ucsc.edu              (831) 297-2117
# 10           napathak@ucsc.edu              (408) 219-2297
# 11           ssachde3@ucsc.edu              (559) 287-6393
# 12            bbehera@ucsc.edu              (510) 936-3079
# 13           yzhan596@ucsc.edu              (510) 789-9297
# 14  brianduong122333@gmail.com              (925) 351-7575
# 15             matiqi@ucsc.edu              (925) 309-9550
# 16           sindurka@ucsc.edu              (408) 508-1721
# 17            nolwest@ucsc.edu              (661) 340-3539
# 18           jelliot1@ucsc.edu              (424) 280-0203
# 19             sthiru@ucsc.edu              (510) 770-4337
#
#                                 Major(s)         Year   Area
# 0                 Mathematics, Economics       Senior  530.0
# 1          Computer Science, Mathematics       Junior  415.0
# 2                            No response     Freshman  510.0
# 3                       Computer Science     Freshman  213.0
# 4   Technology, Information & Management       Senior  661.0
# 5                   Computer Engineering    Sophomore  669.0
# 6                       Computer Science    Sophomore  925.0
# 7          Computer Science: Game Design       Junior  650.0
# 8                   Computer Engineering     Freshman  510.0
# 9                            No response  No response  831.0
# 10                      Computer Science     Freshman  408.0
# 11                      Computer Science       Junior  559.0
# 12         Computer Science, Mathematics       Junior  510.0
# 13                      Computer Science       Junior  510.0
# 14                      Computer Science     Freshman  925.0
# 15  Technology, Information & Management     Freshman  925.0
# 16                  Computer Engineering    Sophomore  408.0
# 17                      Computer Science       Junior  661.0
# 18                  Computer Engineering     Freshman  424.0
# 19         Computer Science: Game Design     Freshman  510.0

# %% [markdown]
# #### 1.3.1 Region extraction
# To extract location information from area codes we'll need to use another dataset. This will be good practice in combining datasets!.
#
# The second dataset we'll use is is table of cities with associated area codes:
#
# (https://github.com/ravisorg/Area-Code-Geolocation-Database/blob/master/us-area-code-cities.csv)[https://github.com/ravisorg/Area-Code-Geolocation-Database/blob/master/us-area-code-cities.csv]

# %%
area_loc = pd.read_csv('us-area-code-cities.csv', header = None)

# %%
# Out:
# array([0, 1, 2, 3, 4, 5], dtype=int64)

# %%
area_loc.head()
# Out:
#      0               1           2   3         4         5
# 0  201         Bayonne  New Jersey  US  40.66871 -74.11431
# 1  201     Bergenfield  New Jersey  US  40.92760 -73.99736
# 2  201  Cliffside Park  New Jersey  US  40.82149 -73.98764
# 3  201       Englewood  New Jersey  US  40.89288 -73.97264
# 4  201       Fair Lawn  New Jersey  US  40.94038 -74.13181

# %% [markdown]
# We drop superfluous columns with geographical coordinates:

# %%
area_loc.drop([3,4,5], axis = 1, inplace = True)

# %%
area_loc.rename(columns =  {0:'Code', 1:'City', 2:'State'})
# Out:
#       Code                City                 State
# 0      201             Bayonne            New Jersey
# 1      201         Bergenfield            New Jersey
# 2      201      Cliffside Park            New Jersey
# 3      201           Englewood            New Jersey
# 4      201           Fair Lawn            New Jersey
# 5      201            Fort Lee            New Jersey
# 6      201          Hackensack            New Jersey
# 7      201             Hoboken            New Jersey
# 8      201         Jersey City            New Jersey
# 9      201              Kearny            New Jersey
# 10     201        North Bergen            New Jersey
# 11     201             Paramus            New Jersey
# 12     201           Ridgewood            New Jersey
# 13     201             Teaneck            New Jersey
# 14     201          Union City            New Jersey
# 15     201       West New York            New Jersey
# 16     202          Washington  District of Columbia
# 17     203          Bridgeport           Connecticut
# 18     203             Danbury           Connecticut
# 19     203          East Haven           Connecticut
# 20     203             Meriden           Connecticut
# 21     203             Milford           Connecticut
# 22     203           Naugatuck           Connecticut
# 23     203           New Haven           Connecticut
# 24     203         North Haven           Connecticut
# 25     203             Norwalk           Connecticut
# 26     203             Shelton           Connecticut
# 27     203            Stamford           Connecticut
# 28     203           Stratford           Connecticut
# 29     203            Trumbull           Connecticut
# ...    ...                 ...                   ...
# 2736   980      South Gastonia        North Carolina
# 2737   980        Huntersville        North Carolina
# 2738   980          Kannapolis        North Carolina
# 2739   980            Matthews        North Carolina
# 2740   980              Monroe        North Carolina
# 2741   980           Salisbury        North Carolina
# 2742   980         Statesville        North Carolina
# 2743   984                Apex        North Carolina
# 2744   984                Cary        North Carolina
# 2745   984         Chapel Hill        North Carolina
# 2746   984              Durham        North Carolina
# 2747   984           Goldsboro        North Carolina
# 2748   984        West Raleigh        North Carolina
# 2749   984             Sanford        North Carolina
# 2750   985               Houma             Louisiana
# 2751   985             Laplace             Louisiana
# 2752   985             Slidell             Louisiana
# 2753   989            Bay City              Michigan
# 2754   989             Midland              Michigan
# 2755   989      Mount Pleasant              Michigan
# 2756   989             Saginaw              Michigan
# 2757   989             Saginaw              Michigan
# 2758   854    North Charleston        South Carolina
# 2759   854            Florence        South Carolina
# 2760   854         Goose Creek        South Carolina
# 2761   854  Hilton Head Island        South Carolina
# 2762   854      Mount Pleasant        South Carolina
# 2763   854  North Myrtle Beach        South Carolina
# 2764   854    North Charleston        South Carolina
# 2765   854         Summerville        South Carolina
#
# [2766 rows x 3 columns]

# %% [markdown]
# Group along area codes:

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-43baf6073135> in <module>
# ----> 1 area_loc.stack('Code')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in stack(self, level, dropna)
#    5927             return stack_multiple(self, level, dropna=dropna)
#    5928         else:
# -> 5929             return stack(self, level, dropna=dropna)
#    5930
#    5931     def unstack(self, level=-1, fill_value=None):
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in stack(frame, level, dropna)
#     477
#     478     # Will also convert negative level numbers and check if out of bounds.
# --> 479     level_num = frame.columns._get_level_number(level)
#     480
#     481     if isinstance(frame.columns, MultiIndex):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _get_level_number(self, level)
#    1425
#    1426     def _get_level_number(self, level):
# -> 1427         self._validate_index_level(level)
#    1428         return 0
#    1429
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _validate_index_level(self, level)
#    1422         elif level != self.name:
#    1423             raise KeyError('Level %s must be same as name (%s)' %
# -> 1424                            (level, self.name))
#    1425
#    1426     def _get_level_number(self, level):
#
# KeyError: 'Level Code must be same as name (None)'

# %% [markdown]
# ## 2 Exploration

# %%
plt.style.use('seaborn')
